# %% [markdown]
# # Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv(r"Amazon Sale Report.csv")
# Out:
# C:\Users\yash5\AppData\Local\Temp\ipykernel_3500\556524421.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"Amazon Sale Report.csv")

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.duplicated().any().sum()
# Out:
# 0

# %%
df['fulfilled-by'].value_counts()
# Out:
# fulfilled-by
# Easy Ship    39277
# Name: count, dtype: int64

# %%
for column in df.columns:
    print(df[column].value_counts())
    print("-"*20)
# Out:
# index
# 0         1
# 85979     1
# 85992     1
# 85991     1
# 85990     1
#          ..
# 42986     1
# 42985     1
# 42984     1
# 42983     1
# 128974    1
# Name: count, Length: 128975, dtype: int64
# --------------------
# Order ID
# 171-5057375-2831560    12
# 403-4984515-8861958    12
# 403-0173977-3041148    11
# 404-9932919-6662730    11
# 408-3317403-1729937    10
#                        ..
# 403-2697348-7766749     1
# 405-0271223-6692335     1
# 406-7498475-4257161     1
# 402-2493916-3621929     1
# 408-7436540-8728312     1
# Name: count, Length: 120378, dtype: int64
# --------------------
# Date
# 05-03-22    2085
# 05-02-22    2079
# 05-04-22    2015
# 04-14-22    1883
# 04-15-22    1853
#             ...
# 06-23-22    1090
# 06-24-22    1028
# 06-25-22    1026
# 06-29-22     658
# 03-31-22     171
# Name: count, Length: 91, dtype: int64
# --------------------
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64
# --------------------
# Fulfilment
# Amazon      89698
# Merchant    39277
# Name: count, dtype: int64
# --------------------
# Sales Channel
# Amazon.in     128851
# Non-Amazon       124
# Name: count, dtype: int64
# --------------------
# ship-service-level
# Expedited    88615
# Standard     40360
# Name: count, dtype: int64
# --------------------
# Style
# JNE3797    4224
# JNE3405    2263
# J0230      1868
# SET268     1860
# J0341      1630
#            ...
# BTM004        1
# SET036        1
# JNE3157       1
# JNE3355       1
# SET045        1
# Name: count, Length: 1377, dtype: int64
# --------------------
# SKU
# JNE3797-KR-L       773
# JNE3797-KR-M       657
# JNE3797-KR-S       587
# JNE3405-KR-L       535
# J0230-SKD-M        507
#                   ...
# BTM004-XXXL          1
# BL090-XS             1
# BTM045-PP-M          1
# SET034-KR-NP-XS      1
# SET045-KR-NP-M       1
# Name: count, Length: 7195, dtype: int64
# --------------------
# Category
# Set              50284
# kurta            49877
# Western Dress    15500
# Top              10622
# Ethnic Dress      1159
# Blouse             926
# Bottom             440
# Saree              164
# Dupatta              3
# Name: count, dtype: int64
# --------------------
# Size
# M       22711
# L       22132
# XL      20876
# XXL     18096
# S       17090
# 3XL     14816
# XS      11161
# 6XL       738
# 5XL       550
# 4XL       427
# Free      378
# Name: count, dtype: int64
# --------------------
# ASIN
# B09SDXFFQ1    773
# B09SDY8DCT    657
# B09SDYQ3WG    587
# B081WSCKPQ    535
# B08XNJG8B1    507
#              ...
# B08QGLTM6G      1
# B08W8DBLXF      1
# B09TL1F68S      1
# B07MY3MVW3      1
# B07N81TFNY      1
# Name: count, Length: 7190, dtype: int64
# --------------------
# Courier Status
# Shipped      109487
# Unshipped      6681
# Cancelled      5935
# Name: count, dtype: int64
# --------------------
# Qty
# 1     115780
# 0      12807
# 2        341
# 3         32
# 4          9
# 5          2
# 15         1
# 9          1
# 13         1
# 8          1
# Name: count, dtype: int64
# --------------------
# currency
# INR    121180
# Name: count, dtype: int64
# --------------------
# Amount
# 399.00    5442
# 771.00    2797
# 735.00    2436
# 0.00      2343
# 487.00    2293
#           ...
# 558.10       1
# 551.42       1
# 973.00       1
# 727.60       1
# 639.00       1
# Name: count, Length: 1410, dtype: int64
# --------------------
# ship-city
# BENGALURU                                      11217
# HYDERABAD                                       8074
# MUMBAI                                          6126
# NEW DELHI                                       5795
# CHENNAI                                         5421
#                                                ...
# Khandavalli, peravali mandal, west godavari        1
# Bhayander west                                     1
# JAKHALMANDI                                        1
# Arariya                                            1
# Halol                                              1
# Name: count, Length: 8955, dtype: int64
# --------------------
# ship-state
# MAHARASHTRA               22260
# KARNATAKA                 17326
# TAMIL NADU                11483
# TELANGANA                 11330
# UTTAR PRADESH             10638
#                           ...
# Mizoram                       1
# rajsthan                      1
# Punjab/Mohali/Zirakpur        1
# Rajsthan                      1
# orissa                        1
# Name: count, Length: 69, dtype: int64
# --------------------
# ship-postal-code
# 201301.0    1006
# 122001.0     688
# 560037.0     632
# 560068.0     619
# 560076.0     581
#             ...
# 144006.0       1
# 829108.0       1
# 263637.0       1
# 815353.0       1
# 629152.0       1
# Name: count, Length: 9459, dtype: int64
# --------------------
# ship-country
# IN    128942
# Name: count, dtype: int64
# --------------------
# promotion-ids
# IN Core Free Shipping 2015/04/08 23-48-5-108                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        46100
# Duplicated A12RHGVGRWOT3S 1560498941486                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               489
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-PZHUW6DZX4BPS,Amazon PLCC Free-Financing Universal Merchant AAT-XX7G3ZRJJJ5LG,Amazon PLCC Free-Financing Universal Merchant AAT-LEHCKNDBJG64E,Amazon PLCC Free-Financing Universal Merchant AAT-DJVHCEV7D7RQY,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4                                                                                                                                                                                                                                                                                                458
# Duplicated AYTJSBA8ZOP16 1567159860988                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                433
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-G5ZRX4BZOIODU,Amazon PLCC Free-Financing Universal Merchant AAT-PZHUW6DZX4BPS,Amazon PLCC Free-Financing Universal Merchant AAT-ETXQ3XXWMRXBG,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4                                                                                                                                                                                                                                                                                                316
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-FYWJCQHU2XQ2U,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-URPEBMPS7TSPE,VPC-44571-41445561 Coupon,Amazon PLCC Free-Financing Universal Merchant AAT-L2DLP5YGE5766,Amazon PLCC Free-Financing Universal Merchant AAT-5ZEB2OGNZ32MC,Amazon PLCC Free-Financing Universal Merchant AAT-2MN4SWBDTUSNI,Amazon PLCC Free-Financing Universal Merchant AAT-4VFZUZS2EO5J2,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4                                                                                                                                        1
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-FYWJCQHU2XQ2U,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-URPEBMPS7TSPE,VPC-44571-41445527 Coupon,Amazon PLCC Free-Financing Universal Merchant AAT-2MN4SWBDTUSNI,Amazon PLCC Free-Financing Universal Merchant AAT-4VFZUZS2EO5J2,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4                                                                                                                                                                                                                                                                                                                                        1
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-FYWJCQHU2XQ2U,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-WSJLDN3X7KEMO,Amazon PLCC Free-Financing Universal Merchant AAT-VL6FGQVGQVXUS,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-URPEBMPS7TSPE,VPC-44571-41445561 Coupon,Amazon PLCC Free-Financing Universal Merchant AAT-L2DLP5YGE5766,Amazon PLCC Free-Financing Universal Merchant AAT-5ZEB2OGNZ32MC,Amazon PLCC Free-Financing Universal Merchant AAT-2MN4SWBDTUSNI,Amazon PLCC Free-Financing Universal Merchant AAT-4VFZUZS2EO5J2,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4        1
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-FYWJCQHU2XQ2U,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,VPC-44571-38708638 Coupon,Amazon PLCC Free-Financing Universal Merchant AAT-URPEBMPS7TSPE,Amazon PLCC Free-Financing Universal Merchant AAT-2MN4SWBDTUSNI,Amazon PLCC Free-Financing Universal Merchant AAT-4VFZUZS2EO5J2,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4                                                                                                                                                                                                                                                                                                                                        1
# Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-EWAPBB6BDRGM6,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-NT3ZJJGQ3JK3Q,Amazon PLCC Free-Financing Universal Merchant AAT-5SHH3G55USK5C,Amazon PLCC Free-Financing Universal Merchant AAT-TNYBHEAO7HOHO,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4,Amazon PLCC Free-Financing Universal Merchant AAT-QMFZ3M7T5NPDS,Amazon PLCC Free-Financing Universal Merchant #MP-pmilan-1601980554292                                                                                                                                                           1
# Name: count, Length: 5787, dtype: int64
# --------------------
# B2B
# False    128104
# True        871
# Name: count, dtype: int64
# --------------------
# fulfilled-by
# Easy Ship    39277
# Name: count, dtype: int64
# --------------------
# Unnamed: 22
# False    79925
# Name: count, dtype: int64
# --------------------

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Date categories

# %%
frist_date = df['Date'].max()
last_date = df['Date'].min()
print("frist_date of order:-",frist_date)
print('last_date of order:-',last_date)
# Out:
# frist_date of order:- 06-29-22
# last_date of order:- 03-31-22

# %%
# Date to week
# Date column ko datetime me convert karo
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# Week number nikalna
df['Week'] = df['Date'].dt.isocalendar().week

# %%
df['Week'].value_counts()
# Out:
# Week
# 16    12125
# 18    11937
# 15    11763
# 14    11225
# 17    11047
# 23    10441
# 22     9834
# 24     8879
# 21     8847
# 19     8519
# 20     8280
# 25     8212
# 13     4887
# 26     2979
# Name: count, dtype: Int64

# %% [markdown]
# ### Status categories clean

# %%
df['Status'].value_counts()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
def simplify_status(x):
    if x in ['Shipped', 'Shipped - Delivered to Buyer', 
             'Shipped - Picked Up', 'Shipped - Out for Delivery']:
        return 'Shipped_Done'
    elif x in ['Cancelled', 'Shipped - Rejected by Buyer', 
               'Shipped - Returned to Seller', 'Shipped - Returning to Seller',
               'Shipped - Lost in Transit', 'Shipped - Damaged']:
        return 'Cancelled'
    else:
        return 'Problem_Pending'

df['Status_Group'] = df['Status'].apply(simplify_status)

print(df['Status_Group'].value_counts())
# Out:
# Status_Group
# Shipped_Done       107581
# Cancelled           20447
# Problem_Pending       947
# Name: count, dtype: int64

# %% [markdown]
# ### Style groping

# %%
top_styles = df['Style'].value_counts().nlargest(20).index
top_styles
# Out:
# Index(['JNE3797', 'JNE3405', 'J0230', 'SET268', 'J0341', 'J0003', 'SET324',
#        'SET345', 'JNE3373', 'JNE3440', 'JNE3399', 'JNE3800', 'SET331',
#        'JNE3567', 'JNE3291', 'SET291', 'JNE3798', 'J0339', 'JNE3368', 'J0008'],
#       dtype='object', name='Style')

# %%
df['Style_Group'] = df['Style'].apply(lambda x: x if x in top_styles else 'Other')
df['Style_Group'].value_counts()
# Out:
# Style_Group
# Other      101715
# JNE3797      4224
# JNE3405      2263
# J0230        1868
# SET268       1860
# J0341        1630
# J0003        1627
# SET324       1284
# SET345       1250
# JNE3373      1173
# JNE3440      1054
# JNE3399      1049
# JNE3800      1033
# SET331        966
# JNE3567       896
# JNE3291       865
# SET291        855
# JNE3798       849
# J0339         842
# JNE3368       841
# J0008         831
# Name: count, dtype: int64

# %%
## Amount range

# %%
df['Amount'].describe()
# Out:
# count    121180.000000
# mean        648.561465
# std         281.211687
# min           0.000000
# 25%         449.000000
# 50%         605.000000
# 75%         788.000000
# max        5584.000000
# Name: Amount, dtype: float64

# %% [markdown]
# ## ship-city

# %%
df["ship-city"].value_counts()
# Out:
# ship-city
# BENGALURU                                      11217
# HYDERABAD                                       8074
# MUMBAI                                          6126
# NEW DELHI                                       5795
# CHENNAI                                         5421
#                                                ...
# Khandavalli, peravali mandal, west godavari        1
# Bhayander west                                     1
# JAKHALMANDI                                        1
# Arariya                                            1
# Halol                                              1
# Name: count, Length: 8955, dtype: int64

# %%
df["ship-city"] = df["ship-city"].str.upper()

# %%
df["ship-city"].value_counts()
# Out:
# ship-city
# BENGALURU                11898
# HYDERABAD                 9125
# MUMBAI                    7122
# NEW DELHI                 6340
# CHENNAI                   6284
#                          ...
# KIM                          1
# EDAPALLY NORTH PO            1
# MANDI GOBINDGARH             1
# CHERUPUZHA                   1
# PRAYAGRAJ (ALLAHABAD)        1
# Name: count, Length: 7297, dtype: int64

# %%
df["ship-state"].unique()
# Out:
# array(['MAHARASHTRA', 'KARNATAKA', 'PUDUCHERRY', 'TAMIL NADU',
#        'UTTAR PRADESH', 'CHANDIGARH', 'TELANGANA', 'ANDHRA PRADESH',
#        'RAJASTHAN', 'DELHI', 'HARYANA', 'ASSAM', 'JHARKHAND',
#        'CHHATTISGARH', 'ODISHA', 'KERALA', 'MADHYA PRADESH',
#        'WEST BENGAL', 'NAGALAND', 'Gujarat', 'UTTARAKHAND', 'BIHAR',
#        'JAMMU & KASHMIR', 'PUNJAB', 'HIMACHAL PRADESH',
#        'ARUNACHAL PRADESH', 'MANIPUR', 'Goa', 'MEGHALAYA', 'GOA',
#        'TRIPURA', 'LADAKH', 'DADRA AND NAGAR', 'SIKKIM', 'Delhi', nan,
#        'ANDAMAN & NICOBAR ', 'Punjab', 'Rajshthan', 'Manipur',
#        'rajasthan', 'Odisha', 'NL', 'Bihar', 'MIZORAM', 'punjab',
#        'New Delhi', 'Rajasthan', 'Punjab/Mohali/Zirakpur', 'Puducherry',
#        'delhi', 'RJ', 'Chandigarh', 'orissa', 'LAKSHADWEEP', 'goa', 'PB',
#        'APO', 'Arunachal Pradesh', 'AR', 'Pondicherry', 'Sikkim',
#        'Arunachal pradesh', 'Nagaland', 'bihar', 'Mizoram', 'rajsthan',
#        'Orissa', 'Rajsthan', 'Meghalaya'], dtype=object)

# %%
df["ship-state"] = df["ship-state"].str.upper()

# %%
df['ship-postal-code'].value_counts()
# Out:
# ship-postal-code
# 201301.0    1006
# 122001.0     688
# 560037.0     632
# 560068.0     619
# 560076.0     581
#             ...
# 144006.0       1
# 829108.0       1
# 263637.0       1
# 815353.0       1
# 629152.0       1
# Name: count, Length: 9459, dtype: int64

# %%
top_code = df['ship-postal-code'].value_counts().nlargest(20).index
top_code
# Out:
# Index([201301.0, 122001.0, 560037.0, 560068.0, 560076.0, 560043.0, 401107.0,
#        500072.0, 560100.0, 560066.0, 560078.0, 500049.0, 248001.0, 500090.0,
#        411057.0, 500084.0, 560102.0, 560064.0, 500089.0, 411014.0],
#       dtype='float64', name='ship-postal-code')

# %%
df['ship-postal-code'] = df['ship-postal-code'].apply(lambda x: x if x in top_code else 100000.0)

# %%
df['ship-postal-code'].value_counts()
# Out:
# ship-postal-code
# 100000.0    118902
# 201301.0      1006
# 122001.0       688
# 560037.0       632
# 560068.0       619
# 560076.0       581
# 560043.0       500
# 401107.0       493
# 500072.0       490
# 560100.0       489
# 560066.0       464
# 560078.0       447
# 500049.0       437
# 248001.0       432
# 500090.0       430
# 411057.0       428
# 500084.0       415
# 560102.0       400
# 560064.0       385
# 500089.0       372
# 411014.0       365
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                index                           Date            Qty  \
# count  128975.000000                         128975  128975.000000
# mean    64487.000000  2022-05-12 11:49:27.951928576       0.904431
# min         0.000000            2022-03-31 00:00:00       0.000000
# 25%     32243.500000            2022-04-20 00:00:00       1.000000
# 50%     64487.000000            2022-05-10 00:00:00       1.000000
# 75%     96730.500000            2022-06-04 00:00:00       1.000000
# max    128974.000000            2022-06-29 00:00:00      15.000000
# std     37232.019822                            NaN       0.313354
#
#               Amount  ship-postal-code       Week
# count  121180.000000     128975.000000   128975.0
# mean      648.561465     127229.885683  19.068657
# min         0.000000     100000.000000       13.0
# 25%       449.000000     100000.000000       16.0
# 50%       605.000000     100000.000000       19.0
# 75%       788.000000     100000.000000       22.0
# max      5584.000000     560102.000000       26.0
# std       281.211687     102125.846586   3.706868

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ...   ship-state ship-postal-code ship-country  \
# 0            Set  ...  MAHARASHTRA         100000.0           IN
# 1          kurta  ...    KARNATAKA         100000.0           IN
# 2          kurta  ...  MAHARASHTRA         100000.0           IN
# 3  Western Dress  ...   PUDUCHERRY         100000.0           IN
# 4            Top  ...   TAMIL NADU         100000.0           IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22 Week  Status_Group Style_Group
# 0         NaN   17     Cancelled       Other
# 1         NaN   17  Shipped_Done       Other
# 2         NaN   17  Shipped_Done       Other
# 3         NaN   17     Cancelled       J0341
# 4         NaN   17  Shipped_Done       Other
#
# [5 rows x 27 columns]

# %% [markdown]
# # Data Preprocessing
# ## 1 . Handle Missing Values

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code          0
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# Week                      0
# Status_Group              0
# Style_Group               0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='most_frequent')
df[['ship-city']] = si.fit_transform(df[['ship-city']])
df[['ship-state']] = si.fit_transform(df[['ship-state']])

# %%
df["Amount"] = df["Amount"].fillna(df.groupby("Category")["Amount"].transform("mean"))

# %%
df['Courier Status'] = df['Courier Status'].fillna('Shipped')

# %%
df["fulfilled-by"] = df["fulfilled-by"].fillna("Unknown")
df["Unnamed: 22"] = df["Unnamed: 22"].fillna(True)
# Out:
# C:\Users\yash5\AppData\Local\Temp\ipykernel_3500\1314225879.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Unnamed: 22"] = df["Unnamed: 22"].fillna(True)

# %% [markdown]
# # Drop Coloum

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22', 'Week', 'Status_Group',
#        'Style_Group'],
#       dtype='object')

# %%
df.shape
# Out:
# (128975, 27)

# %%
drop_clo = ['index',
'Order ID','ASIN'
,'ship-country'
,'currency'
,"promotion-ids",
'SKU','Date','Style','Status',
]
df_cleaned = df.drop(columns=drop_clo)

# %%
df_cleaned.shape
# Out:
# (128975, 17)

# %%
df_cleaned.isnull().sum()
# Out:
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# B2B                   0
# fulfilled-by          0
# Unnamed: 22           0
# Week                  0
# Status_Group          0
# Style_Group           0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
df_cleaned.head()
# Out:
#   Fulfilment Sales Channel  ship-service-level       Category Size  \
# 0   Merchant      Amazon.in           Standard            Set    S
# 1   Merchant      Amazon.in           Standard          kurta  3XL
# 2     Amazon      Amazon.in          Expedited          kurta   XL
# 3   Merchant      Amazon.in           Standard  Western Dress    L
# 4     Amazon      Amazon.in          Expedited            Top  3XL
#
#   Courier Status  Qty  Amount    ship-city   ship-state  ship-postal-code  \
# 0        Shipped    0  647.62       MUMBAI  MAHARASHTRA          100000.0
# 1        Shipped    1  406.00    BENGALURU    KARNATAKA          100000.0
# 2        Shipped    1  329.00  NAVI MUMBAI  MAHARASHTRA          100000.0
# 3        Shipped    0  753.33   PUDUCHERRY   PUDUCHERRY          100000.0
# 4        Shipped    1  574.00      CHENNAI   TAMIL NADU          100000.0
#
#      B2B fulfilled-by  Unnamed: 22  Week  Status_Group Style_Group
# 0  False    Easy Ship         True    17     Cancelled       Other
# 1  False    Easy Ship         True    17  Shipped_Done       Other
# 2   True      Unknown         True    17  Shipped_Done       Other
# 3  False    Easy Ship         True    17     Cancelled       J0341
# 4  False      Unknown         True    17  Shipped_Done       Other

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Fulfilment          128975 non-null  object
#  1   Sales Channel       128975 non-null  object
#  2   ship-service-level  128975 non-null  object
#  3   Category            128975 non-null  object
#  4   Size                128975 non-null  object
#  5   Courier Status      128975 non-null  object
#  6   Qty                 128975 non-null  int64
#  7   Amount              128975 non-null  float64
#  8   ship-city           128975 non-null  object
#  9   ship-state          128975 non-null  object
#  10  ship-postal-code    128975 non-null  float64
#  11  B2B                 128975 non-null  bool
#  12  fulfilled-by        128975 non-null  object
#  13  Unnamed: 22         128975 non-null  bool
#  14  Week                128975 non-null  UInt32
#  15  Status_Group        128975 non-null  object
#  16  Style_Group         128975 non-null  object
# dtypes: UInt32(1), bool(2), float64(2), int64(1), object(11)
# memory usage: 14.6+ MB

# %%
B2B_map = { False : 0 , True : 1 }
df_cleaned['B2B']=df['B2B'].map(B2B_map)

# %%
for coloum in df_cleaned.select_dtypes('object'):
    print(coloum)
# Out:
# Fulfilment
# Sales Channel
# ship-service-level
# Category
# Size
# Courier Status
# ship-city
# ship-state
# fulfilled-by
# Status_Group
# Style_Group

# %%
from sklearn.preprocessing import LabelEncoder
lab_en = LabelEncoder()
for coloum in df_cleaned.select_dtypes('object'):
    df_cleaned[coloum] = lab_en.fit_transform(df_cleaned[coloum])

# %%
df_cleaned
# Out:
#         Fulfilment  Sales Channel   ship-service-level  Category  Size  \
# 0                1               0                   1         5     7
# 1                1               0                   1         8     0
# 2                0               0                   0         8     8
# 3                1               0                   1         7     5
# 4                0               0                   0         6     0
# ...            ...             ...                 ...       ...   ...
# 128970           0               0                   0         8     8
# 128971           0               0                   0         5     6
# 128972           0               0                   0         7    10
# 128973           0               0                   0         5     9
# 128974           0               0                   0         5     7
#
#         Courier Status  Qty   Amount  ship-city  ship-state  ship-postal-code  \
# 0                    1    0   647.62       4331          22          100000.0
# 1                    1    1   406.00        810          17          100000.0
# 2                    1    1   329.00       4665          22          100000.0
# 3                    1    0   753.33       5457          33          100000.0
# 4                    1    1   574.00       1314          41          100000.0
# ...                ...  ...      ...        ...         ...               ...
# 128970               1    1   517.00       2540          42          100000.0
# 128971               1    1   999.00       2337          13          100000.0
# 128972               1    1   690.00       2540          42          500049.0
# 128973               1    1  1199.00       2388          12          100000.0
# 128974               1    1   696.00       5609           8          100000.0
#
#         B2B  fulfilled-by  Unnamed: 22  Week  Status_Group  Style_Group
# 0         0             0         True    17             0           15
# 1         0             0         True    17             2           15
# 2         1             1         True    17             2           15
# 3         0             0         True    17             0            4
# 4         0             1         True    17             2           15
# ...     ...           ...          ...   ...           ...          ...
# 128970    0             1        False    22             2           15
# 128971    0             1        False    22             2           15
# 128972    0             1        False    22             2           15
# 128973    0             1        False    22             2           15
# 128974    0             1        False    22             2            0
#
# [128975 rows x 17 columns]

# %%
df['Unnamed: 22'].value_counts()
# Out:
# Unnamed: 22
# False    79925
# True     49050
# Name: count, dtype: int64

# %%
import seaborn as sns
corr = df_cleaned.corr(numeric_only=True)

plt.figure(figsize=(12,6))
sns.heatmap(
    corr,
    annot=True,
    annot_kws={'size' : 6},
    cmap = 'coolwarm'
)
# Out:
# <Axes: >

# %%
df['fulfilled-by'].value_counts()
# Out:
# fulfilled-by
# Unknown      89698
# Easy Ship    39277
# Name: count, dtype: int64

# %%
df['Fulfilment'].value_counts()
# Out:
# Fulfilment
# Amazon      89698
# Merchant    39277
# Name: count, dtype: int64

# %%
# df_cleaned['rupi_per_pod'] = df_cleaned['Amount']/df_cleaned['Qty']

# %%
 # df_cleaned['rupi_per_pod'].value_counts()

# %%
df_cleaned.describe()
# Out:
#           Fulfilment  Sales Channel   ship-service-level       Category  \
# count  128975.000000   128975.000000       128975.000000  128975.000000
# mean        0.304532        0.000961            0.312929       6.414010
# std         0.460211        0.030992            0.463687       1.521719
# min         0.000000        0.000000            0.000000       0.000000
# 25%         0.000000        0.000000            0.000000       5.000000
# 50%         0.000000        0.000000            0.000000       7.000000
# 75%         1.000000        0.000000            1.000000       8.000000
# max         1.000000        1.000000            1.000000       8.000000
#
#                 Size  Courier Status            Qty         Amount  \
# count  128975.000000   128975.000000  128975.000000  128975.000000
# mean        6.359574        1.005784       0.904431     648.718085
# std         2.862824        0.312705       0.313354     276.089292
# min         0.000000        0.000000       0.000000       0.000000
# 25%         5.000000        1.000000       1.000000     455.927108
# 50%         7.000000        1.000000       1.000000     612.000000
# 75%         8.000000        1.000000       1.000000     788.000000
# max        10.000000        2.000000      15.000000    5584.000000
#
#            ship-city     ship-state  ship-postal-code            B2B  \
# count  128975.000000  128975.000000     128975.000000  128975.000000
# mean     3341.631440      25.311836     127229.885683       0.006753
# std      2016.080177      13.710483     102125.846586       0.081901
# min         0.000000       0.000000     100000.000000       0.000000
# 25%      1431.500000      17.000000     100000.000000       0.000000
# 50%      3066.000000      22.000000     100000.000000       0.000000
# 75%      4798.000000      41.000000     100000.000000       0.000000
# max      7296.000000      46.000000     560102.000000       1.000000
#
#         fulfilled-by       Week   Status_Group    Style_Group
# count  128975.000000   128975.0  128975.000000  128975.000000
# mean        0.695468  19.068657       1.675588      13.902097
# std         0.460211   3.706868       0.732286       3.429463
# min         0.000000       13.0       0.000000       0.000000
# 25%         0.000000       16.0       2.000000      15.000000
# 50%         1.000000       19.0       2.000000      15.000000
# 75%         1.000000       22.0       2.000000      15.000000
# max         1.000000       26.0       2.000000      20.000000

# %% [markdown]
# # OWN we Predict aumount

# %%
x= df_cleaned.drop('Amount',axis= 1)
y = df_cleaned['Amount']

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
x= st.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test ,y_train , y_test = train_test_split(x,y ,
                                    test_size=0.2,random_state=42)

# %% [markdown]
# # Appliying LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score ,precision_score
r2_LinearRegression = r2_score(y_test,y_pred)
print('r2_score: - ',(r2_LinearRegression)*100,'%')
# Out:
# r2_score: -  28.560778050381185 %

# %% [markdown]
# # Applying losso

# %%
from sklearn.linear_model import Lasso , Ridge
lasso = Lasso()
pipe = lasso.fit(X_train,y_train)
y_pred = lasso.predict(X_test) 
r2_Lasso = r2_score(y_test,y_pred)
print('r2_score: - ',r2_Lasso)
# Out:
# r2_score: -  0.28236253821554647

# %% [markdown]
# # Applying Ridge

# %%
from sklearn.linear_model import Lasso , Ridge
Ridge = Ridge()
pipe = Ridge.fit(X_train,y_train)
y_pred = Ridge.predict(X_test) 
r2_Ridge = r2_score(y_test,y_pred)
print('r2_score: - ',r2_Ridge)
# Out:
# r2_score: -  0.2856067985795506

# %%
# Applying DecisionTreeRegressor¶

# %%
from sklearn.tree import DecisionTreeRegressor
 
model = DecisionTreeRegressor(max_depth=21)
model.fit(X_train,y_train)
y_pred = lr.predict(X_test) 
r2_DecisionTreeRegressor = r2_score(y_test,y_pred)
print('r2_score: - ',r2_DecisionTreeRegressor)
# Out:
# r2_score: -  0.28560778050381186

# %%
print('r2_score LinearRegression : - ',r2_LinearRegression)
print('r2_score DecisionTreeRegressor: - ',r2_DecisionTreeRegressor)
print('r2_score r2_Ridge: - ',r2_Ridge)
print('r2_score Lasso: - ',r2_Lasso)
# Out:
# r2_score LinearRegression : -  0.28560778050381186
# r2_score DecisionTreeRegressor: -  0.28560778050381186
# r2_score r2_Ridge: -  0.2856067985795506
# r2_score Lasso: -  0.28236253821554647

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(
    n_estimators=201,
    random_state=42
)
model.fit(X_train,y_train)
y_pred = lr.predict(X_test) 
r2_DecisionTreeRegressor = r2_score(y_test,y_pred)
print('r2_score: - ',r2_DecisionTreeRegressor)
# Out:
# r2_score: -  0.28560778050381186

# %%
dt = DecisionTreeRegressor(max_depth=12, min_samples_split=16, random_state=42)

bagging = BaggingRegressor(
    dt,        
    n_estimators=201,
    random_state=42
)

bagging.fit(X_train,y_train)
y_read = bagging.predict(X_test)
y_pred = bagging.predict(X_train)

#print('precision test data: - ',precision_score(y_read,y_test)*100,'%')

print('accuracy train data: - ', r2_score(y_train, y_pred)*100,"%")
print('accuracy test data: - ', r2_score(y_test, y_read)*100,"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 3
#       1 dt = DecisionTreeRegressor(max_depth=12, min_samples_split=16, random_state=42)
# ----> 3 bagging = BaggingRegressor(
#       4     dt,
#       5     n_estimators=201,
#       6     random_state=42
#       7 )
#       9 bagging.fit(X_train,y_train)
#      10 y_read = bagging.predict(X_test)
#
# NameError: name 'BaggingRegressor' is not defined

# %%
df_cleaned.columns

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt

# Train model
xgb_model = xgb.XGBRegressor(
    n_estimators=300,
    max_depth=8,
    learning_rate=0.1,
    random_state=42
)
xgb_model.fit(X_train, y_train)

# Predictions
y_test_pred = xgb_model.predict(X_test)
print("Test R²:", r2_score(y_test, y_test_pred))
print("Test RMSE:", mean_squared_error(y_test, y_test_pred, squared=False))

# Feature importance plot
xgb.plot_importance(xgb_model, importance_type='gain', max_num_features=15)
plt.show()
# Out:
# Test R²: 0.5499502511140908
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 17
#      15 y_test_pred = xgb_model.predict(X_test)
#      16 print("Test R²:", r2_score(y_test, y_test_pred))
# ---> 17 print("Test RMSE:", mean_squared_error(y_test, y_test_pred, squared=False))
#      19 # Feature importance plot
#      20 xgb.plot_importance(xgb_model, importance_type='gain', max_num_features=15)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\anaconda3\Lib\inspect.py:3267, in Signature.bind(self, *args, **kwargs)
#    3262 def bind(self, /, *args, **kwargs):
#    3263     """Get a BoundArguments object, that maps the passed `args`
#    3264     and `kwargs` to the function's signature.  Raises `TypeError`
#    3265     if the passed arguments can not be bound.
#    3266     """
# -> 3267     return self._bind(args, kwargs)
#
# File ~\anaconda3\Lib\inspect.py:3256, in Signature._bind(self, args, kwargs, partial)
#    3246         raise TypeError(
#    3247             'got some positional-only arguments passed as '
#    3248             'keyword arguments: {arg!r}'.format(
#    (...)
#    3253             ),
#    3254         )
#    3255     else:
# -> 3256         raise TypeError(
#    3257             'got an unexpected keyword argument {arg!r}'.format(
#    3258                 arg=next(iter(kwargs))))
#    3260 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'

# %% [markdown]
# # furture enggering

# %%
drop_clo = ['ship-service-level',
            'fulfilled-by','Unnamed: 22','ship-postal-code'
]
df_cleaned = df_cleaned.drop(columns=drop_clo)

# %%
df_cleaned.head()
# Out:
#    Fulfilment  Sales Channel   Category  Size  Courier Status  Qty  Amount  \
# 0           1               0         5     7               1    0  647.62
# 1           1               0         8     0               1    1  406.00
# 2           0               0         8     8               1    1  329.00
# 3           1               0         7     5               1    0  753.33
# 4           0               0         6     0               1    1  574.00
#
#    ship-city  ship-state  B2B  Week  Status_Group  Style_Group
# 0       4331          22    0    17             0           15
# 1        810          17    0    17             2           15
# 2       4665          22    1    17             2           15
# 3       5457          33    0    17             0            4
# 4       1314          41    0    17             2           15

# %%
cols=['Status','Fulfilment','Sales Channel ','ship-service-level','Qty','Amount','Category',
 'Courier Status','B2B','Month']
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22', 'Week', 'Status_Group',
#        'Style_Group'],
#       dtype='object')

# %%
df_cleaned.columns
# Out:
# Index(['Fulfilment', 'Sales Channel ', 'Category', 'Size', 'Courier Status',
#        'Qty', 'Amount', 'ship-city', 'ship-state', 'B2B', 'Week',
#        'Status_Group', 'Style_Group'],
#       dtype='object')

# %%
'Size','Style_Group'

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(xgb_model)
plt.show()
